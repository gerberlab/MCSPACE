# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
from mcspace.utils import pickle_load
from mcspace.data_utils import get_data, get_human_timeseries_dataset, get_mouse_diet_perturbations_dataset
from mcspace.utils import get_device, pickle_load, pickle_save, get_summary_stats, MODEL_FILE
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 1086-9223
#
#  Directory of C:\Users\Gary\Dropbox (Partners HealthCare)\research_bwh\MCSPACE\MCSPACE\mcspace\paper\semi_synthetic
#
# 03/24/2024  04:39 PM    <DIR>          .
# 03/24/2024  04:27 PM    <DIR>          ..
# 03/24/2024  04:39 PM    <DIR>          .ipynb_checkpoints
# 03/24/2024  04:28 PM    <DIR>          base_run
# 03/24/2024  04:38 PM                72 check_base_runs.ipynb
# 03/07/2024  11:35 AM             7,990 check_sim_datasets.ipynb
# 03/06/2024  02:05 PM            45,627 fit_negbin_human_data.ipynb
# 03/06/2024  02:08 PM            37,637 fit_negbin_mouse_data.ipynb
# 03/06/2024  02:33 PM             6,755 generate_semisynthetic_datasets.py
# 03/07/2024  02:39 PM             6,782 higher_scale_generate_semisynthetic_datasets.py
# 03/24/2024  04:38 PM               246 negbin_fit_params_Human_data.pkl
# 03/24/2024  04:38 PM               246 negbin_fit_params_Mouse_data.pkl
# ...

# %%
ls "base_run/Human"
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 1086-9223
#
#  Directory of C:\Users\Gary\Dropbox (Partners HealthCare)\research_bwh\MCSPACE\MCSPACE\mcspace\paper\semi_synthetic\base_run\Human
#
# 03/24/2024  04:28 PM    <DIR>          .
# 03/24/2024  04:28 PM    <DIR>          ..
# 03/24/2024  04:28 PM            17,064 ELBO_loss.png
# 03/24/2024  04:28 PM           109,451 model.pt
# 03/24/2024  04:28 PM             4,050 results.pkl
#                3 File(s)        130,565 bytes
#                2 Dir(s)  601,642,360,832 bytes free

# %%
basepath = Path("./")
humanpath = basepath / "base_run" / "Human"
mousepath = basepath / "base_run" / "Mouse"

# %%
model = torch.load(humanpath / MODEL_FILE)

# %%
humanres = pickle_load(humanpath / "results.pkl")
mouseres = pickle_load(mousepath / "results.pkl")

# %%
humanres.keys()
# Out:
# dict_keys(['pert_bf', 'beta', 'theta'])

# %%
humantheta = humanres['theta']

# %%
mousetheta = mouseres['theta']

# %%
humantheta.shape
# Out:
# (25, 36)

# %%
mousetheta.shape
# Out:
# (25, 69)

# %%
fig, ax = plt.subplots()
sns.heatmap(humantheta.T, cmap="Blues", vmin=0, vmax=1, ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
sns.heatmap(mousetheta.T, cmap="Blues", vmin=0, vmax=1, ax=ax)
# Out:
# <Axes: >
